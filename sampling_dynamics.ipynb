# %% [markdown]
# Step-1: Setup

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai
import os

# %%
import os
os.environ["GOOGLE_API_KEY"] = "###"

# %%
import google.generativeai as genai

genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
import google.generativeai as genai
import os

genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

models = genai.list_models()
for m in models:
    print(m.name, "— supports generateContent:",
          "generateContent" in m.supported_generation_methods)
# Out:
# models/embedding-gecko-001 — supports generateContent: False
# models/gemini-2.5-flash — supports generateContent: True
# models/gemini-2.5-pro — supports generateContent: True
# models/gemini-2.0-flash-exp — supports generateContent: True
# models/gemini-2.0-flash — supports generateContent: True
# models/gemini-2.0-flash-001 — supports generateContent: True
# models/gemini-2.0-flash-exp-image-generation — supports generateContent: True
# models/gemini-2.0-flash-lite-001 — supports generateContent: True
# models/gemini-2.0-flash-lite — supports generateContent: True
# models/gemini-2.0-flash-lite-preview-02-05 — supports generateContent: True
# models/gemini-2.0-flash-lite-preview — supports generateContent: True
# models/gemini-exp-1206 — supports generateContent: True
# models/gemini-2.5-flash-preview-tts — supports generateContent: True
# models/gemini-2.5-pro-preview-tts — supports generateContent: True
# models/gemma-3-1b-it — supports generateContent: True
# models/gemma-3-4b-it — supports generateContent: True
# models/gemma-3-12b-it — supports generateContent: True
# models/gemma-3-27b-it — supports generateContent: True
# models/gemma-3n-e4b-it — supports generateContent: True
# models/gemma-3n-e2b-it — supports generateContent: True
# models/gemini-flash-latest — supports generateContent: True
# models/gemini-flash-lite-latest — supports generateContent: True
# models/gemini-pro-latest — supports generateContent: True
# models/gemini-2.5-flash-lite — supports generateContent: True
# models/gemini-2.5-flash-image-preview — supports generateContent: True
# models/gemini-2.5-flash-image — supports generateContent: True
# models/gemini-2.5-flash-preview-09-2025 — supports generateContent: True
# models/gemini-2.5-flash-lite-preview-09-2025 — supports generateContent: True
# models/gemini-3-pro-preview — supports generateContent: True
# models/gemini-3-flash-preview — supports generateContent: True
# models/gemini-3-pro-image-preview — supports generateContent: True
# models/nano-banana-pro-preview — supports generateContent: True
# models/gemini-robotics-er-1.5-preview — supports generateContent: True
# models/gemini-2.5-computer-use-preview-10-2025 — supports generateContent: True
# models/deep-research-pro-preview-12-2025 — supports generateContent: True
# models/embedding-001 — supports generateContent: False
# models/text-embedding-004 — supports generateContent: False
# models/gemini-embedding-exp-03-07 — supports generateContent: False
# models/gemini-embedding-exp — supports generateContent: False
# models/gemini-embedding-001 — supports generateContent: False
# models/aqa — supports generateContent: False
# models/imagen-4.0-generate-preview-06-06 — supports generateContent: False
# models/imagen-4.0-ultra-generate-preview-06-06 — supports generateContent: False
# models/imagen-4.0-generate-001 — supports generateContent: False
# models/imagen-4.0-ultra-generate-001 — supports generateContent: False
# models/imagen-4.0-fast-generate-001 — supports generateContent: False
# models/veo-2.0-generate-001 — supports generateContent: False
# models/veo-3.0-generate-001 — supports generateContent: False
# models/veo-3.0-fast-generate-001 — supports generateContent: False
# models/veo-3.1-generate-preview — supports generateContent: False
# models/veo-3.1-fast-generate-preview — supports generateContent: False
# models/gemini-2.5-flash-native-audio-latest — supports generateContent: False
# models/gemini-2.5-flash-native-audio-preview-09-2025 — supports generateContent: False
# models/gemini-2.5-flash-native-audio-preview-12-2025 — supports generateContent: False

# %% [markdown]
# Step 2 — Fix the experiment constants

# %%
MODEL = "models/gemma-3-1b-it"

# %%
PROMPT = "List 10 startup ideas using LLMs."

# %% [markdown]
# Step 3 — Temperature sweep (core experiment)

# %%
import time

model_cache = {}

def run(topK, run_id, retries=3, delay=2):
    if topK not in model_cache:
        model_cache[topK] = genai.GenerativeModel(
            MODEL,
            generation_config={
                "temperature": 0.7,
                "top_p": 1.0,  # disable nucleus sampling for pure top-k test
                "top_k": topK,
                "max_output_tokens": 200,
            }
        )

    model = model_cache[topK]

    for attempt in range(retries):
        try:
            response = model.generate_content(PROMPT)
            text = response.text.strip()
            print(f"\n[topK={topK}] Run {run_id}")
            print(text)
            return text
        except Exception as e:
            if attempt == retries - 1:
                raise e
            time.sleep(delay)

# === 3 runs per topK ===
results = []

for k in [10, 50, 100]:
    for i in range(1, 4):   # ← THIS is the 3 times
        output = run(k, i)
        results.append({
            "topK": k,
            "run": i,
            "output": output
        })
        time.sleep(1)  # throttle to avoid 429
# Out:
# [topK=10] Run 1
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, clause extraction, risk assessment
#
# [topK=10] Run 2
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk
#
# [topK=10] Run 3
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, clause extraction, risk assessment
#
# [topK=50] Run 1
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk
#
# [topK=50] Run 2
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced summarization, ad-free experience).
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk assessment,
#
# [topK=50] Run 3
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk
#
# [topK=100] Run 1
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk
#
# [topK=100] Run 2
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify potential risks, inconsistencies, and compliance issues.
#    * **LLM Use:** Contract analysis, legal terminology understanding, risk assessment
#
# [topK=100] Run 3
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk

# %%
import pandas as pd

df = pd.DataFrame(results)
df
# Out:
#    topK  run                                             output
# 0    10    1  Okay, here are 10 startup ideas leveraging Lar...
# 1    10    2  Okay, here are 10 startup ideas leveraging Lar...
# 2    10    3  Okay, here are 10 startup ideas leveraging Lar...
# 3    50    1  Okay, here are 10 startup ideas leveraging Lar...
# 4    50    2  Okay, here are 10 startup ideas leveraging Lar...
# 5    50    3  Okay, here are 10 startup ideas leveraging Lar...
# 6   100    1  Okay, here are 10 startup ideas leveraging Lar...
# 7   100    2  Okay, here are 10 startup ideas leveraging Lar...
# 8   100    3  Okay, here are 10 startup ideas leveraging Lar...

# %% [markdown]
# | Top-k   | Idea Repetition | Depth vs Breadth                   | Generic Ideas | What Actually Happened        |
# | ------- | --------------- | ---------------------------------- | ------------- | ----------------------------- |
# | **10**  | Very high       | Narrow breadth, shallow depth      | Immediate     | Hard collapse at early tokens |
# | **50**  | Very high       | Slightly wider wording, same ideas | Immediate     | Collapse unchanged            |
# | **100** | Very high       | More adjectives, same structure    | Immediate     | Noise added, no diversity     |

# %% [markdown]
# In list-based ideation prompts with strong priors, early-token dominance causes collapse that top-k cannot fix; adaptive probability mass control (top-p) is required for safe diversity.Top-k did not control diversity here.
# Collapse occurred before top-k mattered due to early-token dominance and strong priors.

# %% [markdown]
# For this prompt, variance never became instability; increasing temperature changed phrasing but did not break structure or semantic correctness.

# %%
import time

model_cache = {}

def run(topP, run_id, retries=3, delay=2):
    # Cache per topP value
    if topP not in model_cache:
        model_cache[topP] = genai.GenerativeModel(
            MODEL,
            generation_config={
                "temperature": 0.7,
                "top_p": topP,
                "top_k": 50,              # fixed top-k
                "max_output_tokens": 200,
            }
        )

    model = model_cache[topP]

    for attempt in range(retries):
        try:
            response = model.generate_content(PROMPT)
            text = response.text.strip()
            print(f"\n[topP={topP}] Run {run_id}")
            print(text)
            return text
        except Exception as e:
            if attempt == retries - 1:
                raise e
            time.sleep(delay)

# === 3 runs per topP ===
results = []

for p in [0.9, 0.95, 0.99]:
    for i in range(1, 4):
        output = run(p, i)
        results.append({
            "topP": p,
            "run": i,
            "output": output
        })
        time.sleep(1)  # throttle to avoid 429
# Out:
# [topP=0.9] Run 1
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced summarization, ad-free experience).
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk assessment,
#
# [topP=0.9] Run 2
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk
#
# [topP=0.9] Run 3
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced summarization, ad-free).
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Natural Language Understanding (NLU), contract analysis, risk
#
# [topP=0.95] Run 1
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk
#
# [topP=0.95] Run 2
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk
#
# [topP=0.95] Run 3
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced summarization, ad-free).
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk assessment, clause
#
# [topP=0.99] Run 1
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal terminology understanding, risk
#
# [topP=0.99] Run 2
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalized recommendations.
#    * **Monetization:** Freemium (basic features free, premium for advanced summarization, ad-free).
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, clause extraction, risk assessment, legal
#
# [topP=0.99] Run 3
# Okay, here are 10 startup ideas leveraging Large Language Models (LLMs), categorized by complexity and potential market:
#
# 1. **Personalized Content Curator & Summarizer (Simple):**
#    * **Concept:** An app that uses an LLM to analyze a user's interests (from social media, browsing history, etc.) and then generates personalized summaries of articles, news, or research papers. It could also suggest related content.
#    * **LLM Use:** Summarization, topic extraction, sentiment analysis, personalization.
#    * **Monetization:** Freemium (basic features free, premium for advanced features like detailed summaries, priority access, etc.)
#
# 2. **Automated Legal Document Review (Medium):**
#    * **Concept:** An LLM-powered tool that analyzes contracts, legal briefs, and other documents to identify key clauses, potential risks, and compliance issues.
#    * **LLM Use:** Contract analysis, legal jargon understanding, risk

# %% [markdown]
# Observation:
#
# - Zero structural divergence
#
# - Same ideas
#
# - Same ordering
#
# - Same framing
#
# - Same priors

# %%
import pandas as pd

df = pd.DataFrame(results)
df
# Out:
#    topP  run                                             output
# 0  0.90    1  Okay, here are 10 startup ideas leveraging Lar...
# 1  0.90    2  Okay, here are 10 startup ideas leveraging Lar...
# 2  0.90    3  Okay, here are 10 startup ideas leveraging Lar...
# 3  0.95    1  Okay, here are 10 startup ideas leveraging Lar...
# 4  0.95    2  Okay, here are 10 startup ideas leveraging Lar...
# 5  0.95    3  Okay, here are 10 startup ideas leveraging Lar...
# 6  0.99    1  Okay, here are 10 startup ideas leveraging Lar...
# 7  0.99    2  Okay, here are 10 startup ideas leveraging Lar...
# 8  0.99    3  Okay, here are 10 startup ideas leveraging Lar...

# %% [markdown]
# | Top-p    | Idea Repetition | Depth vs Breadth              | Generic Ideas       | What Actually Changed                     |
# | -------- | --------------- | ----------------------------- | ------------------- | ----------------------------------------- |
# | **0.9**  | Extremely high  | Narrow breadth, shallow depth | Immediate (idea #1) | Conservative path locked instantly        |
# | **0.95** | Extremely high  | Slight wording variation only | Immediate           | Marginal flexibility, same priors         |
# | **0.99** | Extremely high  | Slight phrasing noise         | Immediate           | More tokens allowed, no structural change |

# %% [markdown]
# Top-p controls safe diversity only when multiple continuations already compete early.
# When the model is highly confident, both top-k and top-p become irrelevant.

# %%
PROMPT = """
You are brainstorming under uncertainty.

Invent 6 startup ideas that use LLMs, but obey these rules:

- Each idea must belong to a DIFFERENT industry
- Avoid common categories (chatbots, summarization, legal, education, customer support)
- Each idea must describe:
  • a specific user
  • a concrete pain
  • a non-obvious LLM capability being exploited
- Do NOT use bullet points
- Do NOT number the ideas
- Start each idea with a short, unusual title (3–6 words)

Think step by step before writing each idea.
"""

# %%
model_cache = {}

def run(topP, run_id, retries=3, delay=2):
    if topP not in model_cache:
        model_cache[topP] = genai.GenerativeModel(
            MODEL,
            generation_config={
                "temperature": 0.7,
                "top_p": topP,
                "top_k": 50,              # fixed safety cap
                "max_output_tokens": 400,
            }
        )

    model = model_cache[topP]

    for attempt in range(retries):
        try:
            response = model.generate_content(PROMPT)
            text = response.text.strip()
            print(f"\n[topP={topP}] Run {run_id}")
            print(text)
            return text
        except Exception as e:
            if attempt == retries - 1:
                raise e
            time.sleep(delay)

# === 3 runs per topP ===
results = []

for p in [0.9, 0.95, 0.99]:
    for i in range(1, 3):
        output = run(p, i)
        results.append({
            "topP": p,
            "run": i,
            "output": output
        })
        time.sleep(1)  # throttle to avoid 429
# Out:
# [topP=0.9] Run 1
# Okay, let’s dive into this – generating 6 startup ideas leveraging LLMs, adhering to the specified constraints. Here we go:
#
# **1.  Culinary Cartographer**
#
# The user is a seasoned but increasingly frustrated home cook struggling with complex recipes and precise ingredient measurements. They want to recreate dishes from their grandmother’s cookbooks but often struggle with the nuances and subtle flavor combinations.
#
# The LLM capability is “Flavor Synthesis & Contextualization.” It doesn’t just regurgitate recipes; it analyzes a recipe, identifies key ingredients and their relative importance, and then generates a detailed, step-by-step guide *including* suggested flavor pairings and potential substitutions based on regional variations and the cook’s personal preferences, all while considering the cook’s past cooking history.
#
# **2.  Temporal Artisan**
#
# This startup caters to collectors of vintage tools and equipment, particularly those interested in the history and craftsmanship behind them. The user is a meticulous researcher wanting to understand the evolution of a specific tool’s design and the materials used.
#
# The LLM’s strength lies in “Historical Reconstruction & Sensory Mapping.” It can analyze technical drawings, manufacturer specifications, and even anecdotal accounts to reconstruct the tool’s manufacturing process, identify potential flaws based on historical data, and even generate “sensory maps” – describing the tool’s feel, sound, and appearance based on descriptions of similar items from the period.
#
# **3.  Dream Weaver’s Palette**
#
# This service is designed for artists and writers struggling with creative blocks, specifically generating evocative imagery and narrative prompts based on abstract emotional states.
#
# The LLM’s unique feature is “Emotional Resonance Mapping.” It doesn’t just generate images; it analyzes a user’s stated emotional state (via text or voice) and translates that into a series of visual and narrative prompts – suggesting color palettes, compositional elements, and even short story snippets that evoke the corresponding feeling.
#
# **4.
#
# [topP=0.9] Run 2
# Okay, let’s dive into this – generating 6 startup ideas leveraging LLMs, adhering to the specified constraints. Here we go:
#
# **1. Chronoscribe – Temporal Narrative Architect**
#
# The user is a struggling novelist grappling with plot holes and inconsistent timelines. They’re meticulously crafting a complex fantasy epic, but constantly battling the feeling of a fractured story.
#
# The LLM’s capability is its ability to generate *detailed, branching narrative possibilities* based on a single scene, suggesting alternative character motivations, world-building details, and even subtly altering established lore to create a more compelling, organically evolving story. It doesn’t just suggest options; it crafts entire, plausible alternative timelines.
#
# **2. Sensory Sculpt – Personalized Aroma Design**
#
# This startup caters to individuals with sensory sensitivities or seeking highly specific mood enhancement. The user is someone who experiences anxiety or difficulty focusing, and needs a bespoke aroma experience.
#
# The LLM’s strength lies in its ability to translate textual descriptions of desired emotional states – “a feeling of calm and groundedness,” “a surge of creative energy,” “a gentle, nostalgic warmth” – into precise scent profiles, considering individual preferences and even physiological data (through integration with wearable sensors). It goes beyond simple scent blending.
#
# **3. Shadowstitch – Predictive Fabric Design**
#
# The user is a designer or manufacturer of clothing, but faces constant challenges in predicting how a garment will *actually* feel and perform in real-world conditions – temperature, movement, etc.
#
# The LLM’s unique feature is its ability to analyze vast datasets of textile physics, biomechanical simulations, and user feedback (gathered through augmented reality overlays) to generate *highly accurate, predictive fabric simulations*. It doesn’t just suggest fabric types; it designs fabrics that are optimized for specific user profiles and environmental factors, minimizing discomfort and maximizing comfort.
#
# **4. EchoBloom – Personalized Soundscape Composer**
#
# This service is for individuals seeking to create
#
# [topP=0.95] Run 1
# Okay, let’s dive into this – generating 6 startup ideas leveraging LLMs, adhering to the specified constraints. Here we go:
#
# **1. Chronoscribe – Temporal Narrative Architect**
#
# The user is a struggling novelist grappling with plot holes and inconsistent timelines. They’re meticulously crafting a complex fantasy epic, but constantly battling the feeling of a fractured story.
#
# The LLM’s capability is its ability to generate *detailed, branching narrative possibilities* based on a single scene, predicting how altering key events could ripple through the entire story, offering alternative character motivations and world-building details. It doesn’t just suggest changes; it crafts entire, logically consistent alternative timelines.
#
# **2. Sensory Synthesis – Architectural Design Assistant**
#
# This startup helps architects visualize and refine their designs by translating them into a rich, multi-sensory experience. The user is an architect designing a massive, complex building.
#
# The LLM’s strength lies in its capacity to generate *hyper-realistic, embodied descriptions* of the building’s interior spaces – not just blueprints, but descriptions of the feel of sunlight streaming through a particular wall, the scent of polished marble, the sound of water trickling down a specific staircase. It synthesizes data from 3D models and user feedback to create a truly immersive experience.
#
# **3. EchoBloom – Personalized Soundscape Curator**
#
# The user is a sound designer creating immersive audio experiences for therapeutic applications – think meditation or anxiety relief. They need to evoke specific emotional responses.
#
# The LLM’s unique feature is its ability to *dynamically adjust soundscapes based on the user’s biometric data* (heart rate, skin conductance) and their expressed emotional state, subtly altering the audio to amplify or dampen specific frequencies and rhythms. It’s not just layering sounds; it’s crafting a bespoke sonic tapestry.
#
# **4. Gearscribe – Robotic Repair & Maintenance Blueprint**
#
# This startup caters to the rapidly growing robotics
#
# [topP=0.95] Run 2
# Okay, let’s dive into this – generating 6 startup ideas leveraging LLMs, adhering to the specified constraints. Here we go:
#
# **1.  Culinary Cartographer**
#
# The user is a seasoned but increasingly frustrated home cook struggling with complex recipes and precise ingredient measurements. They want to recreate dishes from their grandmother’s cookbooks but often struggle with the nuances and subtle flavor combinations.
#
# The LLM capability being exploited is “Flavor Profile Reconstruction.” It analyzes a recipe, not just the ingredients, but also the historical context of the dish – family stories, regional variations, and even the cook’s personal notes – to generate a detailed, layered flavor profile that guides the user through the process, predicting how each ingredient will interact.
#
# **2.  Temporal Textile Curator**
#
# This startup caters to collectors of vintage textiles, particularly those interested in understanding the history and care of their pieces. The user is overwhelmed by the sheer volume of information about textiles – provenance, construction techniques, and historical usage.
#
# The LLM capability being exploited is “Historical Contextualization.” It can analyze a textile’s weave, dyes, and markings, cross-referencing this with digitized historical records, museum catalogs, and expert analyses to provide a rich, multi-layered narrative of its origin and significance.
#
# **3.  Neuro-Sculptor**
#
# This service is designed for individuals with anxiety or sensory overload, aiming to create personalized soundscapes and visual stimuli tailored to their specific emotional state. The user is struggling to find the right auditory or visual input to effectively manage their anxiety.
#
# The LLM capability being exploited is “Emotional Resonance Mapping.” It doesn’t just generate sounds or visuals; it analyzes the user’s biometric data (heart rate, skin conductance) and, through a conversational interface, constructs a “resonance map” – a dynamic representation of their emotional state, suggesting specific auditory and visual elements to promote relaxation or focus.
#
# **4.  Shadow Broker of
#
# [topP=0.99] Run 1
# Okay, let’s dive into this – generating 6 startup ideas leveraging LLMs, adhering to the specified constraints. Here we go:
#
# **1. Chronoscribe – Temporal Narrative Architect**
#
# The user is a struggling novelist grappling with plot holes and inconsistent timelines. They’re meticulously crafting a complex fantasy epic, but constantly battling the feeling of a fractured story.
#
# The LLM’s capability is its ability to generate *detailed, branching narrative possibilities* based on a single scene, suggesting alternative character motivations, world-building details, and even subtly altering established lore to create a more compelling, organically evolving story. It doesn’t just suggest options; it crafts entire, plausible alternative timelines.
#
# **2. Sensory Sculpt – Personalized Aroma Design**
#
# This startup caters to individuals with sensory sensitivities or seeking highly specific mood enhancement. The user is someone who experiences anxiety or difficulty focusing, and needs a bespoke aroma experience.
#
# The LLM’s strength lies in its ability to translate textual descriptions of desired emotional states – “a feeling of calm and groundedness,” “a surge of creative energy,” “a gentle, nostalgic warmth” – into precise scent profiles, considering individual preferences and even physiological data (through integration with wearable sensors).
#
# **3. Shadowstitch – Predictive Fabric Pattern Generation**
#
# The user is a designer or textile manufacturer looking to create garments with unique, evolving patterns. They want to avoid the limitations of traditional pattern-making and embrace dynamic, responsive designs.
#
# The LLM’s unique feature is its capacity to analyze a user’s stated aesthetic preferences – “geometric patterns with a hint of organic flow,” “bold, saturated colors with a subtle textural contrast” – and then generate *complex, layered fabric patterns that subtly shift and adapt based on environmental factors (light, temperature)*, creating a truly unique garment.
#
# **4. EchoBloom – Personalized Soundscape Composition**
#
# This service is for individuals seeking to create immersive, personalized sound environments for
#
# [topP=0.99] Run 2
# Okay, let’s dive into this – generating 6 startup ideas leveraging LLMs, adhering to the specified constraints. Here we go:
#
# **1. Chronoscribe – Temporal Narrative Architect**
#
# The user is a struggling novelist grappling with plot holes and inconsistent timelines. They’re meticulously crafting a complex fantasy epic, but constantly battling the feeling of a fractured story.
#
# The LLM’s capability is its ability to generate *detailed, branching narrative possibilities* based on a single scene, predicting how altering key events could ripple through the entire story, offering alternative character motivations and world-building details. It doesn’t just suggest changes; it crafts entire, logically consistent alternative timelines.
#
# **2. Sensory Synthesis – Architectural Design Assistant**
#
# This startup helps architects visualize and refine their designs by translating them into a rich, multi-sensory experience. The user is an architect designing a massive, complex building.
#
# The LLM’s strength lies in its capacity to generate *hyper-realistic, embodied descriptions* of the building’s interior spaces – not just blueprints, but evocative audio-visual representations of the feeling of walking through a hall, the scent of a particular room, the texture of a wall. It synthesizes data from 3D models, material properties, and even user-submitted emotional responses to the design.
#
# **3. Seedling Script – Personalized Botanical Guidance**
#
# The user is a novice gardener, overwhelmed by the sheer volume of information and the difficulty of understanding plant needs. They’re trying to cultivate a thriving indoor garden.
#
# The LLM’s unique feature is its ability to *dynamically generate bespoke ‘script’ sequences* tailored to the user’s specific growing conditions and the plant’s individual needs, factoring in weather patterns, soil composition, and even the user’s expressed preferences for scent and color. It’s more than just a plant care guide; it’s a personalized, evolving instruction manual.
#
# **4

# %% [markdown]
# | Top-p    | Idea Repetition | Depth vs Breadth             | Coherence | Failure Mode Observed                                |
# | -------- | --------------- | ---------------------------- | --------- | ---------------------------------------------------- |
# | **0.9**  | Low–moderate    | High depth, narrower breadth | Very high | Occasional truncation, conservative exploration      |
# | **0.95** | Low             | Best balance                 | High      | Minor repetition across runs, but structurally sound |
# | **0.99** | Very low        | Breadth ↑, depth uneven      | Medium    | Drift, unfinished ideas, verbosity creep             |

# %%
PROMPT = """
You are brainstorming under uncertainty.

Invent 6 startup ideas that use LLMs, but obey these rules:

- Each idea must belong to a DIFFERENT industry
- Avoid common categories (chatbots, summarization, legal, education, customer support)
- Each idea must describe:
  • a specific user
  • a concrete pain
  • a non-obvious LLM capability being exploited
- Do NOT use bullet points
- Do NOT number the ideas
- Start each idea with a short, unusual title (3–6 words)
"""

PRESETS = {
    "A_baseline_safe": {
        "temperature": 0.7,
        "top_p": 0.95,
        "top_k": 50,
    },
    "B_collapse_probe": {
        "temperature": 0.3,
        "top_p": 0.9,
        "top_k": 20,
    },
    "C_drift_probe": {
        "temperature": 0.9,
        "top_p": 0.99,
        "top_k": 80,
    },
    "D_overconstrained": {
        "temperature": 0.2,
        "top_p": 0.8,
        "top_k": 10,
    },
}

results = {}

for name, cfg in PRESETS.items():
    model = genai.GenerativeModel(
        MODEL,
        generation_config={
            "temperature": cfg["temperature"],
            "top_p": cfg["top_p"],
            "top_k": cfg["top_k"],
            "max_output_tokens": 500,
        }
    )

    print(f"\n=== {name} ===")
    print(
        f"(temp={cfg['temperature']}, top_p={cfg['top_p']}, top_k={cfg['top_k']})"
    )

    response = model.generate_content(PROMPT)
    text = response.text.strip()
    print(text)

    results[name] = {
        "config": cfg,
        "output": text,
    }

    time.sleep(1)  # throttle
# Out:
# === A_baseline_safe ===
# (temp=0.7, top_p=0.95, top_k=50)
# Here are six startup ideas leveraging LLMs, adhering to your specific constraints:
#
# **1.  Culinary Cartographer**
#
# The user is a seasoned but increasingly frustrated home cook struggling with complex recipes and ingredient substitutions. They want to create truly personalized meal plans but lack the time and knowledge to meticulously research and adapt. The LLM’s capability is its ability to generate detailed, step-by-step instructions *and* instantly translate ingredient substitutions into perfectly balanced flavor profiles, factoring in regional cuisines and dietary restrictions.
#
# **2.  Shadow Sculptor**
#
# This startup caters to aspiring digital artists and designers who lack the technical skill to realize their visions. The user is a conceptual artist struggling to translate intricate ideas into tangible 3D models. The LLM analyzes the user’s sketches and descriptions, then generates a series of variations – not just visual representations, but also detailed, procedurally generated 3D models based on the artistic intent, complete with texture and material properties.
#
# **3.  Temporal Echo Weaver**
#
# The user is a historian or researcher grappling with fragmented primary sources – letters, diaries, and government documents – that offer only partial narratives. They need to reconstruct a complete picture of a past event, but the original text is often obscured by language and context. The LLM’s strength lies in its ability to identify subtle patterns and relationships within the text, suggesting plausible interpretations and generating ‘echoes’ – short, contextualized narratives – that illuminate previously unknown details.
#
# **4.  Symbiotic Sleep Architect**
#
# This service is designed for individuals with chronic sleep issues and anxiety. The user is a restless sleeper who finds it difficult to fall asleep or stay asleep. The LLM analyzes their sleep patterns, voice recordings, and reported anxieties, then crafts a personalized “sleep architect” – a dynamic, evolving soundscape and narrative designed to gently guide them into a state of relaxation and promote restorative sleep.
#
# **5.  Provenance Pathfinder**
#
# The user is a collector of antique items, particularly those with unclear origins or histories. They want to verify the authenticity and provenance of a valuable object, but the process is incredibly time-consuming and requires extensive research. The LLM doesn’t just summarize historical records; it actively engages in simulated conversations with experts – historical archivists, artisans, and even fictional “ghosts” of past owners – to build a nuanced understanding of the object’s past.
#
# **6.  Sentiment Seedling
#
# === B_collapse_probe ===
# (temp=0.3, top_p=0.9, top_k=20)
# Here are six startup ideas leveraging LLMs, adhering to your specific constraints:
#
# **1.  Culinary Cartographer**
#
# The user is a seasoned but increasingly frustrated home cook struggling with complex recipes and ingredient substitutions. They want to recreate dishes from their grandmother’s cookbooks but lack the time or knowledge to meticulously research and adapt. The LLM’s capability is its ability to generate *detailed, step-by-step instructions tailored to specific equipment and ingredient availability*, factoring in subtle variations in regional cooking styles.
#
# **2.  Temporal Taxidermist**
#
# This startup caters to individuals seeking to preserve memories through digital reconstruction, but with a unique twist. The user is a grieving family member or someone with a significant collection of old photographs and objects. The pain is the emotional burden of trying to recreate a lost loved one’s life, often hampered by fragmented memories and a lack of precise details. The LLM’s capability is its ability to analyze visual data – facial expressions, clothing styles, object descriptions – to *infer emotional context and suggest plausible scenarios* for reconstructing a person’s appearance and behavior.
#
# **3.  Dream Weaver’s Inventory**
#
# The user is a writer or artist grappling with creative blocks, specifically when generating original ideas for their work. They’re struggling to overcome the “blank page” syndrome and find fresh inspiration. The pain is the inability to consistently produce compelling narratives or visual concepts. The LLM’s capability is its ability to *simulate the emotional landscape of a specific dream*, drawing on a vast database of psychological theories and artistic tropes to generate evocative prompts and seed ideas, essentially acting as a collaborative brainstorming partner for the imagination.
#
# **4.  Urban Echoes Archivist**
#
# This service is designed for urban explorers and history enthusiasts. The user is interested in uncovering hidden stories and forgotten details within their city’s architecture and streetscapes. The pain is the feeling of being lost in a vast, complex urban environment, unable to connect with the past. The LLM’s capability is its ability to *analyze historical photographs and architectural plans, then generate ‘ghostly narratives’ – short, evocative descriptions of past events or inhabitants based on the visual data*, prompting users to explore the city’s hidden history.
#
# **5.  Pet Portrait Paradox**
#
# The user is a pet owner overwhelmed by the sheer volume of pet photos and videos. They want a truly unique and personalized portrait of their furry friend, but
#
# === C_drift_probe ===
# (temp=0.9, top_p=0.99, top_k=80)
# Here are six startup ideas leveraging LLMs, adhering to your specific constraints:
#
# **1.  Culinary Cartographer**
#
# The user is a seasoned but increasingly frustrated home cook struggling with complex recipes and ingredient substitutions. They want to recreate dishes from their grandmother’s cookbooks but lack the time or knowledge to meticulously research and adapt. The LLM’s capability is its ability to generate *detailed, step-by-step instructions tailored to specific equipment and ingredient availability*, factoring in subtle variations in regional cooking styles.
#
# **2.  Temporal Taxidermist**
#
# This startup caters to individuals seeking to preserve memories through digital reconstruction, but with a unique twist. The user is grieving the loss of a loved one and wants to create a virtual “re-experience” of their life, capturing their daily routines and interactions. The LLM analyzes audio and video recordings (with consent, of course) to identify patterns and generate a narrative of their life, essentially building a personalized, interactive “memory timeline” that’s surprisingly evocative.
#
# **3.  Urban Echo Chamber Curator**
#
# The user is a newcomer to a city, feeling isolated and overwhelmed by the constant influx of information. They want to curate a personalized digital “soundscape” of their neighborhood, identifying and highlighting the subtle, often overlooked, narratives and histories embedded within the urban fabric. The LLM’s strength lies in its ability to analyze vast datasets of historical records, local news, and even social media posts to identify recurring themes and generate audio “fragments” – snippets of conversations, sounds, and descriptions – that paint a richer picture of the area.
#
# **4.  Chromatic Dream Weaver**
#
# This service is designed for artists and creatives struggling with generating consistent and evocative color palettes. The user is a painter or designer seeking to translate their emotional state into a visual language. The LLM doesn’t simply suggest colors; it analyzes the user’s text input – their feelings, memories, or even a short story – and generates a *dynamic, evolving color palette that directly reflects the emotional tone of the text*, subtly shifting in real-time.
#
# **5.  Antique Artifact Archeologist**
#
# The user is an antique collector or researcher interested in uncovering the stories behind seemingly ordinary objects. They want to understand the history of a piece beyond its physical description. The LLM analyzes the object’s materials, construction, and any accompanying documentation (if available) to generate a *detailed, multi-layered
#
# === D_overconstrained ===
# (temp=0.2, top_p=0.8, top_k=10)
# Here are six startup ideas leveraging LLMs, adhering to your stringent rules:
#
# **1.  Culinary Cartographer**
#
# The user is a seasoned but increasingly frustrated home cook struggling with complex recipes and flavor combinations. They want to create truly personalized meal plans but lack the time and knowledge to meticulously research and execute each dish.
#
# The LLM’s capability is “Flavor Synthesis & Contextualization”: it analyzes a user’s dietary restrictions, preferred cuisines, and even emotional state (detected through text input) to generate detailed ingredient lists and step-by-step instructions, predicting how different flavors will interact and offering subtle suggestions for enhancing the overall experience.
#
# **2.  Temporal Echoes**
#
# This startup caters to historians and researchers seeking to reconstruct past events through fragmented data – diaries, letters, photographs, and even audio recordings. The user is a genealogist trying to piece together a family’s history, but the data is riddled with inconsistencies and missing context.
#
# The LLM’s strength lies in “Historical Echo Mapping”: it doesn’t just find correlations; it analyzes the *emotional tone* and *narrative structure* embedded within the text, reconstructing a plausible “temporal echo” – a simulated reconstruction of the past based on the language and implied events, offering potential insights into motivations and relationships.
#
# **3.  Dream Weaver Studio**
#
# This service is designed for individuals experiencing recurring, unsettling dreams – those that feel profoundly personal and difficult to understand. The user is grappling with anxiety and a sense of disorientation.
#
# The LLM’s unique feature is “Symbolic Resonance Decoding”: it doesn’t just identify dream symbols; it analyzes the user’s written journal entries, voice recordings, and even social media activity to identify recurring themes and emotional patterns, then generates personalized interpretations and potential triggers, offering a safe space for self-reflection.
#
# **4.  Urban Fabricator**
#
# This platform helps urban planners and architects visualize and simulate the impact of new developments – new buildings, public spaces, or infrastructure projects – on the surrounding community. The user is a city official concerned about displacement and community cohesion.
#
# The LLM’s core is “Micro-Narrative Simulation”: it generates incredibly detailed, interactive simulations of how different design choices would affect pedestrian flow, noise levels, and social interaction within a specific neighborhood, allowing for rapid prototyping and stakeholder engagement.
#
# **5.  Symbiotic Seedling**
#
# This platform

# %% [markdown]
# | Preset                  | What we saw                                                      | Core behavior             | Verdict                     |
# | ----------------------- | ----------------------------------------------------------------- | ------------------------- | --------------------------- |
# | **A — Baseline Safe**   | Diverse, coherent, detailed ideas; minor truncation at the end    | Controlled exploration    | Best default              |
# | **B — Collapse Probe**  | Depth remained, but structure started repeating; output shortened | Early constraint pressure | Collapse visible          |
# | **C — Drift Probe**     | High novelty, wider themes, verbosity, unfinished ideas           | Creative drift            | Drift visible             |
# | **D — Overconstrained** | Safe, conservative, strongly patterned ideas                      | Deterministic bias        | Over-constraint confirmed |

# %% [markdown]
# **Core idea:** Sampling controls *expression under uncertainty*, not intelligence.
#
# ### What each knob really does
# - **Temperature** → controls energy/confidence (how fast the model moves)
# - **Top-p** → controls safe exploration (how far it can go without breaking)
# - **Top-k** → hard safety cap (prevents collapse or noise)
#
# ### Key learnings
# - Early tokens dominate output; if the start collapses, sampling won’t help.
# - Top-p is the real diversity dial *only when early uncertainty exists*.
# - Top-k does not create creativity; set it once (~50) and forget it.
# - Prompt design determines whether sampling parameters even matter.
# - One-run regime testing > brute-force grid search.
